# %% [markdown]
# Recreating and Testing the Alternative Criticality Score Algorithm \\
# Author: Blaise Swartwood

# %%
#importing required packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import math

# %% [markdown]
# Recreating only the alternative criticality score algorithm

# %%
#accessing data file
df = pd.read_csv('CSDataAsCSV.csv', usecols=[i for i in range(6, 18) if i != 16])
df.head()
# Out:
#    created_since  updated_since  contributor_count  org_count  \
# 0            131              0               5000         10
# 1            209              0               2044          5
# 2            162              0               3472          9
# 3             97              0               4367          5
# 4            151              0               3579         13
#
#    commit_frequency  recent_release_count  updated_issues_count  \
# 0           1555.33                    69                   552
# 1             70.83                    49                   896
# 2             48.37                    67                 36122
# 3            138.08                    65                 86352
# 4            104.13                    69                 27449
#
#    closed_issues_count  issue_comment_frequency  github_mention_count  \
# 0                  266                     3.18              57193965
# 1                  806                    13.15              36120246
# 2                34479                     2.00               1168604
# 3                84020                     2.00                529999
# 4                26723                     2.00                 88134
#
#    criticality_score
# 0            0.92520
# 1            0.89559
# 2            0.88907
# 3            0.88400
# 4            0.87876

# %%
#loading in weights, max threshold, and min threshold
#0 is being used as the default minimum threshold value
data = [[1, 120, 0], [1, 120, 0], [2,5000,0], [1, 10,0],[1, 1000,0],[0.5, 26,0],[0.5, 5000,0],[0.5, 5000,0],[1, 15,0],[2, 500000,0]]
df2 = pd.DataFrame(data, columns=['Weight','Max','Min'])

#an updated change to remove the negative weight of updated_since
df['updated_since'] = 120 - np.minimum(df['updated_since'], 120)
df2
# Out:
#    Weight     Max  Min
# 0     1.0     120    0
# 1     1.0     120    0
# 2     2.0    5000    0
# 3     1.0      10    0
# 4     1.0    1000    0
# 5     0.5      26    0
# 6     0.5    5000    0
# 7     0.5    5000    0
# 8     1.0      15    0
# 9     2.0  500000    0

# %%
#summing the weights of all the features
weight = df2['Weight'].sum()
n = df2.shape[0]
df['alt_crit'] = 0

# %%
#implementation of the alternative criticality score calculation
for i in range(df.shape[0]):
    x = 1
    for index in range(10):
        w = df2['Weight'][index]
        u = df2['Max'][index]
        l = df2['Min'][index]
        s = df.iloc[i, index]
        r = u-l
        val = np.log(1+(np.minimum(np.maximum(s-l,0),r)))/np.log(1+r)
        val *= w/weight
        x *= (1 - val)
    df.loc[i, 'alt_crit'] = (1 - (np.power(x, 1/n))) * 10

# %%
#percent change between original and alternative criticality score
df['alt_percent_change'] = 100 * (df['alt_crit']-df['criticality_score'])/df['criticality_score']

# %%
df.head()
# Out:
#    created_since  updated_since  contributor_count  org_count  \
# 0            131            120               5000         10
# 1            209            120               2044          5
# 2            162            120               3472          9
# 3             97            120               4367          5
# 4            151            120               3579         13
#
#    commit_frequency  recent_release_count  updated_issues_count  \
# 0           1555.33                    69                   552
# 1             70.83                    49                   896
# 2             48.37                    67                 36122
# 3            138.08                    65                 86352
# 4            104.13                    69                 27449
#
#    closed_issues_count  issue_comment_frequency  github_mention_count  \
# 0                  266                     3.18              57193965
# 1                  806                    13.15              36120246
# 2                34479                     2.00               1168604
# 3                84020                     2.00                529999
# 4                26723                     2.00                 88134
#
#    criticality_score  alt_crit  alt_percent_change
# 0            0.92520  0.942394            1.858458
# 1            0.89559  0.909949            1.603332
# 2            0.88907  0.905144            1.807929
# 3            0.88400  0.900406            1.855889
# 4            0.87876  0.891882            1.493272

# %% [markdown]
# Recreating the alternative algorithm while only using the recommended signals from the statistical analysis

# %%
#creating a new datafrome with the weight, max threshold, and min threshold
data = [[0.5, 120, 0], [2, 120, 0], [2,5000, 0], [2, 10, 0],[0.5, 26, 0],[2, 5000, 0],[2, 15, 0]]
df3 = pd.DataFrame(data, columns=['Weight','Max', 'Min'])

# %%
#recalculating weight
weight = df3['Weight'].sum()
df['new_alt_crit'] = 0

# %%
#implementation of alternative algorithm algorithm
for i in range(df.shape[0]):
    x = 1
    for index in range(7):
        w = df3['Weight'][index]
        u = df3['Max'][index]
        l = df3['Min'][index]
        s = df.iloc[i, index]
        r = u-l
        val = np.log(1+(np.minimum(np.maximum(s-l,0),r)))/np.log(1+r)
        val *= w/weight
        x *= (1 - val)
    df.loc[i, 'new_alt_crit'] = (1 - (np.power(x, 1/n))) * 10

# %%
#percent change from original criticality score to alt score with specific signals
df['new_alt_percent_change'] = 100 * (df['new_alt_crit']-df['criticality_score'])/df['criticality_score']

# %%
df.head()
# Out:
#    created_since  updated_since  contributor_count  org_count  \
# 0            131            120               5000         10
# 1            209            120               2044          5
# 2            162            120               3472          9
# 3             97            120               4367          5
# 4            151            120               3579         13
#
#    commit_frequency  recent_release_count  updated_issues_count  \
# 0           1555.33                    69                   552
# 1             70.83                    49                   896
# 2             48.37                    67                 36122
# 3            138.08                    65                 86352
# 4            104.13                    69                 27449
#
#    closed_issues_count  issue_comment_frequency  github_mention_count  \
# 0                  266                     3.18              57193965
# 1                  806                    13.15              36120246
# 2                34479                     2.00               1168604
# 3                84020                     2.00                529999
# 4                26723                     2.00                 88134
#
#    criticality_score  alt_crit  alt_percent_change  new_alt_crit  \
# 0            0.92520  0.942394            1.858458      0.943292
# 1            0.89559  0.909949            1.603332      0.865449
# 2            0.88907  0.905144            1.807929      0.926120
# 3            0.88400  0.900406            1.855889      0.887286
# 4            0.87876  0.891882            1.493272      0.935424
#
#    new_alt_percent_change
# 0                1.955424
# 1               -3.365491
# 2                4.167252
# 3                0.371743
# 4                6.448145

# %%
#saving results to csv
df.to_csv("altCriticalityScore.csv", index=False)
